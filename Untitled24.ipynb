# %% [markdown]
# <a href="https://colab.research.google.com/github/malakkkk4/moons-using-kmeans-and-DBSCAN/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
moons=pd.read_csv('/content/moons.csv')
moons
# Out:
#             X1        X2
# 0     0.674362 -0.444625
# 1     1.547129 -0.239796
# 2     1.601930 -0.230792
# 3     0.014563  0.449752
# 4     1.503476 -0.389164
# ...        ...       ...
# 1495  1.957344  0.187184
# 1496  0.962394  0.384304
# 1497 -0.761893  0.581666
# 1498  1.803858 -0.154705
# 1499  0.203305  0.079049
#
# [1500 rows x 2 columns]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='X1',y='X2',data=moons)
plt.show()

# %%
from sklearn.cluster import KMeans
model=KMeans(n_clusters=2)

# %%
labels=model.fit_predict(moons)
labels
# Out:
# array([1, 1, 1, ..., 0, 1, 0], dtype=int32)

# %%
sns.scatterplot(x='X1',y='X2',data=moons,hue=labels)
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
from sklearn.cluster import DBSCAN
model=DBSCAN(eps=0.2,min_samples=5)

# %%
labels=model.fit_predict(moons)
labels
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
sns.scatterplot(x='X1',y='X2',data=moons,hue=labels)
# Out:
# <Axes: xlabel='X1', ylabel='X2'>
